# %%
cd ..
# Out:
# /Users/nguyen/rebuildingcode/rbc

# %% [markdown]
# # Using `Point`s

# %%
from rbc.point import Point
from rbc.point.utils import plot_points

# %% [markdown]
# `Point`s can be created with `(x, y, z)` as arguments

# %%
p1 = Point(0, 0, 0)
p2 = Point(0, 10, 0)
p3 = Point(10, 10, 0)

# %%
str(p2)
# Out:
# 'Point(0.0, 10.0, 0.0)'

# %%
p4 = Point(1, 2)

# %%
str(p4)
# Out:
# 'Point(1.0, 2.0)'

# %% [markdown]
# You can use the `distance()` method to find the distance between two points.

# %%
p1.distance(p2)
# Out:
# 10.0

# %% [markdown]
# You can create a new `Point` relative to an existing `Point`.

# %%
p5 = Point.relative_to(p3, (0, 25))
p5
# Out:
# Point(10.0, 35.0, 0.0)

# %%
str(p5)
# Out:
# 'Point(10.0, 35.0, 0.0)'

# %% [markdown]
# You can also `move()` `Point`s. This method supports the flexibility for two `(x, y)` or three `(x, y, z)` arguments.

# %%
p5.x, p5.y
# Out:
# (10.0, 35.0)

# %%
p5.distance((5, 5))
# Out:
# 30.4138126514911

# %%
list(p5.coords)[0]
# Out:
# (10.0, 35.0, 0.0)

# %%
p5.has_z
# Out:
# True

# %%
p5.plot()

# %%
plot_points([p1, p2, p3, p4, p5])
